# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("`/ ")
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv("police shootings.csv")
#       2 data.head(5)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
data.shape

# %%
data.isnull().sum()
# Out:
# id                            0
# name                        417
# date                          0
# manner_of_death               0
# armed                       209
# age                         482
# gender                       20
# race                       1460
# city                          0
# state                         0
# signs_of_mental_illness       0
# threat_level                  0
# flee                        875
# body_camera                   0
# longitude                   837
# latitude                    837
# is_geocoding_exact            0
# dtype: int64

# %%
data.state.unique()
# Out:
# array(['WA', 'OR', 'KS', 'CA', 'CO', 'OK', 'AZ', 'IA', 'PA', 'TX', 'OH',
#        'LA', 'MT', 'UT', 'AR', 'IL', 'NV', 'NM', 'MN', 'MO', 'VA', 'NJ',
#        'IN', 'KY', 'MA', 'NH', 'FL', 'ID', 'MD', 'NE', 'MI', 'GA', 'TN',
#        'NC', 'AK', 'NY', 'ME', 'AL', 'MS', 'WI', 'SC', 'DE', 'DC', 'WV',
#        'HI', 'WY', 'ND', 'CT', 'SD', 'VT', 'RI'], dtype=object)

# %%
data['statefn'] = 0
data['statefn'] = data['state'].replace(['WA', 'OR', 'KS', 'CA', 'CO', 'OK', 'AZ', 'IA', 'PA', 'TX', 'OH',
                                        'LA', 'MT', 'UT', 'AR', 'IL', 'NV', 'NM', 'MN', 'MO', 'VA', 'NJ',
                                        'IN', 'KY', 'MA', 'NH', 'FL', 'ID', 'MD', 'NE', 'MI', 'GA', 'TN',
                                        'NC', 'AK', 'NY', 'ME', 'AL', 'MS', 'WI', 'SC', 'DE', 'DC', 'WV',
                                         'HI', 'WY', 'ND', 'CT', 'SD', 'VT', 'RI'],
                                        ['Washington', 'Oregon', 'Kansas', 'California', 'Colorado', 'Oklahoma', 'Arizona',
                                        'Iowa', 'Pennsylvania', 'Texas', 'Ohio', 'Louisiana', 'Montana', 'Utah', 'Arkansas',
                                        'Illinois', 'Nevada', ' New Mexico', 'Minnesota', 'Missouri', 'Virginia', 'New Jersey',
                                        'Indiana', 'Kentucky', 'Massachusetts', 'New Hampshire', 'Florida', 'Idaho', 'Maryland', 'Nebraska',
                                        'Michigan', 'Georgia', 'Tennessee', 'North Carolina', 'Alaska', 'New York', 'Maine',
                                        'Alabama', 'Mississippi', 'Wisconsin', 'South Carolina', 'Delaware', 'Columbia',
                                        'West Virginia', 'Hawai', 'Wyoming', 'North Dakota', 'Connecticut', 'South Dakota',
                                        'Vermont', 'Rhode Island'])

# %%
data
# Out:
#         id                   name        date   manner_of_death        armed  \
# 0        1             Tim Elliot  2015-01-02              shot          gun
# 1        2       Lewis Lee Lembke  2015-01-02              shot          gun
# 2        3     John Paul Quintero  2015-01-03  shot and Tasered      unarmed
# 3        4        Matthew Hoffman  2015-01-04              shot   toy weapon
# 4        5      Michael Rodriguez  2015-01-04              shot     nail gun
# ...    ...                    ...         ...               ...          ...
# 7724  7725                    NaN  2022-09-07              shot  screwdriver
# 7725  7726                    NaN  2022-09-07              shot          gun
# 7726  7727                    NaN  2022-09-07              shot        knife
# 7727  7728  Tyler Michael Gardner  2022-09-07              shot          gun
# 7728  7729  Reginald Lamont Grant  2022-09-07              shot          gun
#
# ...

# %%
data.city.value_counts()
# Out:
# Los Angeles         128
# Phoenix             101
# Houston              87
# San Antonio          66
# Las Vegas            63
#                    ...
# Valdez                1
# Pinetop-Lakeside      1
# Duarte                1
# Perryopolis           1
# Strongs Prairie       1
# Name: city, Length: 3148, dtype: int64

# %%
data.groupby('statefn')[['race']].count().sort_values('race', ascending = False)
# Out:
#                 race
# statefn
# California       876
# Texas            552
# Florida          428
# Arizona          270
# Georgia          223
# Colorado         216
# North Carolina   194
# Ohio             186
# Oklahoma         184
# Tennessee        172
# Missouri         160
# Washington       151
# Illinois         129
# Louisiana        129
# Pennsylvania     127
# Indiana          123
# Alabama          122
#  New Mexico      120
# Virginia         119
# Kentucky         117
# New York         112
# South Carolina   108
# Wisconsin        105
# Michigan         103
# Nevada           101
# Maryland         101
# Oregon           100
# Arkansas          86
# Mississippi       81
# Minnesota         79
# Utah              74
# New Jersey        68
# Kansas            63
# West Virginia     57
# Idaho             50
# Alaska            43
# Montana           39
# Massachusetts     39
# Iowa              39
# Nebraska          36
# Hawai             33
# Maine             26
# ...

# %%
data['signs_of_mental_illness'].value_counts()
# Out:
# False    6089
# True     1640
# Name: signs_of_mental_illness, dtype: int64

# %%
data.groupby(['signs_of_mental_illness'])['armed'].value_counts()
# Out:
# signs_of_mental_illness  armed
# False                    gun                3594
#                          knife               733
#                          unarmed             369
#                          undetermined        280
#                          vehicle             261
#                                             ...
# True                     pipe                  1
#                          vehicle and gun       1
#                          walking stick         1
#                          wasp spray            1
#                          wrench                1
# Name: armed, Length: 156, dtype: int64

# %%
data['race'].value_counts()
# Out:
# W    3198
# B    1686
# H    1128
# A     113
# N      97
# O      47
# Name: race, dtype: int64

# %%
data['race'].isnull().sum()
# Out:
# 1460

# %%
data['race'].value_counts().plot.pie(explode = [0.2,0.1,0.1,0.3,0.3,0.3], shadow = True, autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='race'>

# %%
data['manner_of_death'].value_counts().plot.bar()
# Out:
# <Axes: >
